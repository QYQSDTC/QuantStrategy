# %% [markdown]
# # 同花顺问财选股

# %%
import qstock as qs
from qstock import wencai
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
qs.wencai("一季报预增")
# Out:
# (node:13603) [DEP0040] DeprecationWarning: The `punycode` module is deprecated. Please use a userland alternative instead.
# (Use `node --trace-deprecation ...` to show where the warning was created)
# (node:13611) [DEP0040] DeprecationWarning: The `punycode` module is deprecated. Please use a userland alternative instead.
# (Use `node --trace-deprecation ...` to show where the warning was created)
#          股票代码  股票简称    最新价         最新涨跌幅 业绩预告类型[20250331]  预告净利润[20250331]  \
# 0   300476.SZ  胜宏科技     82  14.301644829             大幅上升        880000000
# 1   301535.SZ  浙江华远    NaN           NaN             大幅上升         39313650
# 2   688208.SH  道通科技  46.86         3.125             大幅上升        190000000
# 3   300181.SZ  佐力药业  15.92    3.30953926               预增        183500000
# 4   301616.SZ  浙江华业    NaN           NaN               预增         16300000
# 5   688757.SH  胜科纳米    NaN           NaN               预增         10750000
# ...

# %%
qs.wencai("三胎概念，人工智能，市值大于100亿")
# Out:
# (node:14474) [DEP0040] DeprecationWarning: The `punycode` module is deprecated. Please use a userland alternative instead.
# (Use `node --trace-deprecation ...` to show where the warning was created)
# (node:14482) [DEP0040] DeprecationWarning: The `punycode` module is deprecated. Please use a userland alternative instead.
# (Use `node --trace-deprecation ...` to show where the warning was created)
#         股票代码  股票简称    最新价         最新涨跌幅  \
# 0  301078.SZ   孩子王  16.15  19.985141159
# 1  002292.SZ  奥飞娱乐   10.9   5.825242718
# 2  300459.SZ   汤姆猫   6.96   5.614567527
# 3  002024.SZ  ST易购   2.17   1.877934272
# 4  300957.SZ   贝泰妮  47.48   1.452991453
# 5  300244.SZ  迪安诊断   17.4   0.811123986
# 6  002123.SZ  梦网科技  17.14   0.705052879
# 7  002261.SZ  拓维信息  34.22  -1.496833621
#
#                                                 所属概念  总市值[20250314]  所属概念数量  \
# 0  人工智能;托育服务;跨境电商;网络直播;三胎概念;电子商务;抖音概念(字节概念);百度概念;...   2.032190e+10      15
# ...

# %%
wencai('拓维信息 2024 年年报')
# Out:
# (node:15359) [DEP0040] DeprecationWarning: The `punycode` module is deprecated. Please use a userland alternative instead.
# (Use `node --trace-deprecation ...` to show where the warning was created)
# {'简介和看点': {'txt1': '<p>\u3000\u3000拓维信息系统股份有限公司主营业务是软件服务与解决方案、AI行业大模型与行业应用、开源鸿蒙行业发行版及创新性产品与解决方案、智能计算。公司基于OpenHarmony，自研面向智慧城市、交通、教育等领域的全场景操作系统；同时基于鲲鹏、昇腾AI，打造自主品牌“兆瀚”智能计算产品和行业标杆应用。是国家规划布局内重点软件企业、中国信创百强企业、鸿蒙生态重要建设者、首批华为云同舟共济战略合作伙伴、鲲鹏战略合作伙伴、昇腾战略合作伙伴。</p>',
#   'impressionLabel':              看点  影响     类型
#   0  过去5年营业收入持续增长  利好   成长能力
#   1   过去5年毛利率持续下滑  利空   盈利能力
#   2      近一年涨停次数多  利好   中期趋势
#   3   机构预测净利润连续大增  利好  分析师观点
#   4        股价高位回调  利空   短期趋势
#   5  近期走势显著弱于市场总体  利空   短期趋势},
#  'txt1': '<p><span style="font-size:12px">以上数据更新于：2025-03-14，数据来源基于市场公开信息，相关解读基于同花顺大数据统计分析。本功能仅做历史数据的回测和展示，任何表述均不构成投资建议，且存在局限性，提醒投资者请勿据此操作，风险自担。</span></p>',
#  'impressionLabel':              看点  影响     类型
#  0  过去5年营业收入持续增长  利好   成长能力
#  1   过去5年毛利率持续下滑  利空   盈利能力
#  2      近一年涨停次数多  利好   中期趋势
# ...

# %%
wencai('杭齿前进基本面')
# Out:
# (node:16650) [DEP0040] DeprecationWarning: The `punycode` module is deprecated. Please use a userland alternative instead.
# (Use `node --trace-deprecation ...` to show where the warning was created)
# {'txt2': '<p>杭齿前进基本面分析如下：  </p>',
#  'container': {'fundTxt':         code 收盘价:不复权 hq_code market_hq_code  股票简称     涨跌     涨跌幅  \
#   0  601177.SH   19.18  601177             17  杭齿前进  -0.03  -0.16%
#
#                 描述      时间区间                                                url  \
#   0  -0.03  -0.16%  20250314  client.html?action=ymtz^webid=2205^stockcode=6...
#
#     涨跌幅:前复权
#   0   -0.16  ,
#   'txt1': '<p><span style="font-size:14px">该公司运营状况良好，多数机构认为该股长期投资价值一般。</span></p><p></p>',
#   'impressionLabel':   second_cls effect          name
#   0       中期趋势     利好      近一年涨停次数多
#   1       短期趋势     利空       近一周内曾跌停
#   2       短期趋势     利空  近期走势显著弱于市场总体
#   3       短期趋势     利空       股价爆发后回调
#   4       短期资金     利好        主力进散户出
#   5       短期趋势     利空        股价高位回调,
# ...
